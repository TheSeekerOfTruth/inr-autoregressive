# %%
import sys
import os
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
sys.path.append(os.path.abspath('../')) 
from src.data.dataset import INRDataset
from src.models.gpt import INRGPT
# %reload_ext tensorboard
print("✅ Environment ready.")
# Out:
# ✅ Environment ready.

# %%
# %tensorboard --logdir ../runs/
# Out:
# Reusing TensorBoard on port 6006 (pid 2124), started 0:00:12 ago. (Use '!kill 2124' to kill it.)
#       <iframe id="tensorboard-frame-6d209093d2a5494b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6d209093d2a5494b");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !cd .. && python train.py
# Out:
# Using device: cuda
# Loading data and configuring splits...
# Initializing INRGPT engine...
# number of parameters: 2.49M
# num decayed parameter tensors: 37, with 2,480,100 parameters
# num non-decayed parameter tensors: 66, with 15,900 parameters
# using fused AdamW: True
# Beginning model training execution...
# --- Epoch 1 Complete | Train Loss: 6.497103 | Val Loss: 5.740666 ---
# --- Epoch 2 Complete | Train Loss: 5.481463 | Val Loss: 5.311245 ---
# --- Epoch 3 Complete | Train Loss: 5.267472 | Val Loss: 5.229790 ---
# --- Epoch 4 Complete | Train Loss: 5.221060 | Val Loss: 5.206520 ---
# Step 59: Learning Rate changed from 1.00e-04 to 5.00e-05
# --- Epoch 5 Complete | Train Loss: 5.204273 | Val Loss: 5.196068 ---
# --- Epoch 6 Complete | Train Loss: 5.198090 | Val Loss: 5.190526 ---
# --- Epoch 7 Complete | Train Loss: 5.193725 | Val Loss: 5.187202 ---
# --- Epoch 8 Complete | Train Loss: 5.190135 | Val Loss: 5.183809 ---
# --- Epoch 9 Complete | Train Loss: 5.187157 | Val Loss: 5.181561 ---
# --- Epoch 10 Complete | Train Loss: 5.184524 | Val Loss: 5.180005 ---
# --- Epoch 11 Complete | Train Loss: 5.182410 | Val Loss: 5.177816 ---
# --- Epoch 12 Complete | Train Loss: 5.180277 | Val Loss: 5.178174 ---
# --- Epoch 13 Complete | Train Loss: 5.178490 | Val Loss: 5.173447 ---
# --- Epoch 14 Complete | Train Loss: 5.176931 | Val Loss: 5.173193 ---
# --- Epoch 15 Complete | Train Loss: 5.175559 | Val Loss: 5.172155 ---
# --- Epoch 16 Complete | Train Loss: 5.174161 | Val Loss: 5.172691 ---
# --- Epoch 17 Complete | Train Loss: 5.173198 | Val Loss: 5.169336 ---
# --- Epoch 18 Complete | Train Loss: 5.172077 | Val Loss: 5.169145 ---
# --- Epoch 19 Complete | Train Loss: 5.170892 | Val Loss: 5.168362 ---
# --- Epoch 20 Complete | Train Loss: 5.169848 | Val Loss: 5.169167 ---
# Training phase successfully completed!
