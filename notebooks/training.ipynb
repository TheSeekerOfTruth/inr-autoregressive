# %%
import sys
import os
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
sys.path.append(os.path.abspath('../')) 
from src.data.dataset import INRDataset
from src.models.gpt import INRGPT
# %reload_ext tensorboard
print("✅ Environment ready.")
# Out:
# ✅ Environment ready.

# %%
# %tensorboard --logdir ../runs/
# Out:
# Reusing TensorBoard on port 6006 (pid 52255), started 1:32:06 ago. (Use '!kill 52255' to kill it.)
#       <iframe id="tensorboard-frame-a9ee4beae028f988" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a9ee4beae028f988");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !cd .. && python train.py
# Out:
# Using device: cuda
# Loading data and configuring splits...
# /home/theseeker/miniconda3/envs/neural-graphs/lib/python3.9/site-packages/torch/utils/data/dataset.py:469: UserWarning: Length of split at index 1 is 0. This might result in an empty dataset.
#   warnings.warn(
# Initializing INRGPT engine...
# number of parameters: 0.02M
# num decayed parameter tensors: 26, with 36,990 parameters
# num non-decayed parameter tensors: 50, with 1,200 parameters
# using fused AdamW: True
# Beginning model training execution...
# Training phase successfully completed!
