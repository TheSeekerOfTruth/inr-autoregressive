# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../src/models/runs/
# Out:
# Reusing TensorBoard on port 6006 (pid 17191), started 0:00:02 ago. (Use '!kill 17191' to kill it.)
#       <iframe id="tensorboard-frame-76837a89f3df7306" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-76837a89f3df7306");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !cd .. && python train.py
# Out:
# python: can't open file '/home/theseeker/ADL4CV/inr-autoregressive/src/models/train.py': [Errno 2] No such file or directory
